# %%
import pandas as pd

# %%
data = pd.read_csv('Delhi_metadata.csv')

# %%
data.head()
# Out:
#   date_of_filing              cino    dt_regis  fil_no  fil_year  reg_no  \
# 0     2017-10-31  DLNW010107362017  2017-11-06    5342      2017     701
# 1     2018-07-02  DLNW010069892018  2018-07-02    3260      2018    2178
# 2     2018-08-09  DLNW010088032018  2018-08-09    4048      2018    2679
# 3     2016-07-28  DLNW010053952016  2016-07-28   19113      2016     202
# 4     2017-08-09  DLNW040021562017  2017-08-25    1574      2017      19
#
#    reg_year date_first_list date_next_list archive  ... transfer_est_name  \
# 0      2017      2017-11-29     2018-04-10       Y  ...                 0
# 1      2018      2018-07-04     2018-07-04       Y  ...                 0
# 2      2018      2018-08-10     2018-08-10       Y  ...                 0
# 3      2016      2016-07-29     2016-07-29       Y  ...                 0
# 4      2017      2017-10-06     2018-01-08       Y  ...                 0
#
#    transfer_est_date  writinfo  processes complex_code court_code iaFiling  \
# ...

# %%
from datetime import datetime
data[data['dt_regis'] == '2018']
# Out:
# Empty DataFrame
# ...
